# %%
1+1
# Out:
# 2

# %%
print("hello!")
# Out:
# hello!

# %%
# integers (int) are whole numbers
5+6
# Out:
# 11

# %%
# floating point (float)are decimal numbers
5/2
# Out:
# 2.5

# %%
type (5/2)
# Out:
# float

# %%
10//3 # integer division (always rounding down)
# Out:
# 3

# %%
10/3
# Out:
# 3.3333333333333335

# %%
10 % 3 # modulo or reminder
# Out:
# 1

# %%
10 ** 3 # exponentiation
# Out:
# 1000

# %%
50 > 25
# Out:
# True

# %%
-15 >= -14.99
# Out:
# False

# %%
20 == 20
# Out:
# True

# %%
# Can include digits, letters, and underscores
# cannot start with a digit
# are case sensitive
degrees_celsius = 25

# %%
degrees_celsius
# Out:
# 25

# %%
degrees_fahrenheit = (9/5)* degrees_celsius + 32

# %%
degrees_fahrenheit
# Out:
# 77.0

# %%
(9/5) *25 +32
# Out:
# 77.0

# %%
degrees_celsius = 0

# %%
degrees_celsius
# Out:
# 0

# %%
degrees_fahrenheit = (9/5)* degrees_celsius + 32

# %%
degrees_fahrenheit
# Out:
# 32.0

# %%
degrees_celsius
# Out:
# 0

# %%
degrees_celsius = degrees_celsius +10 # 0+10

# %%
degrees_celsius
# Out:
# 10

# %%
a = 1

# %%
a
# Out:
# 1

# %%
b = a

# %%
b
# Out:
# 1

# %%
a = 2

# %%
a
# Out:
# 2

# %%
b
# Out:
# 1

# %%
# degrees_celsius = degrees_celsius + 10

# %%
degrees_celsius = 0
degrees_celsius -= 10 # degrees_celsius -10
degrees_celsius
# Out:
# -10

# %%
12 = x
# Out:
#   Cell In[38], line 1
#     12 = x
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
student1_grade = 90
student2_grade = 50
student3_grade = 74
average_grade = (( student1_grade + student2_grade+ student3_grade)/ 3)

# %%
print("it is Tuesday!")
# Out:
# it is Tuesday!

# %%
type(42)
# Out:
# int

# %%
abs (-43)
# Out:
# 43

# %%
round (2/3)
# Out:
# 1

# %%
int(3.99)
# Out:
# 3

# %%
print(abs(round(-2 * 1.5)))
# Out:
# 3

# %%
help(round)
# Out:
# Help on built-in function round in module builtins:
#
# round(number, ndigits=None)
#     Round a number to a given precision in decimal digits.
#
#     The return value is an integer if ndigits is omitted or None.  Otherwise
#     the return value has the same type as the number.  ndigits may be negative.

# %%
round(3.55555, 3)
# Out:
# 3.556

# %%
round(3.55555)
# Out:
# 4

# %%
def c_to_f(degrees_c): # degrees_c = 100
    degrees_f = (9/5) * degrees_c + 32 # degrees_f = 12.2
    return degrees_f

# %%
c_to_f(100)
# Out:
# 212.0

# %%
c_to_f(-11)
# Out:
# 12.2
