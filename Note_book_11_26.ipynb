# %%
def divide(dividend, divisor):
    result = dividend / divisor
    return result

# %%
divide(0, 2) # 0 is assigned to dividend,  2 assigned to divisor
# Out:
# 0.0

# %%
divide(10, 5)
# Out:
# 2.0

# %%
divide(2, 0) # 2 dividend, 0  is divisor
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 divide(2, 0)
#
# Cell In[1], line 2, in divide(dividend, divisor)
#       1 def divide(dividend, divisor):
# ----> 2     result = dividend / divisor
#       3     return result
#
# ZeroDivisionError: division by zero

# %%
def calc_sales_tax(price, tax_rate=0.13):
    sales_tax = price * tax_rate
    return sales_tax

# %%
calc_sales_tax(5)
# Out:
# 0.65

# %%
5 * 0.13
# Out:
# 0.65

# %%
calc_sales_tax(5, 0.08)
# Out:
# 0.4

# %%
5 * 0.08
# Out:
# 0.4

# %%
def calc_total_bill(price, tax_rate=0.13, tip_rate=0.15):
    'calculate total bill with tax and tip'
    tax = price * tax_rate
    tip = price * tip_rate
    total = price + tax + tip
    return total

# %%
calc_total_bill(200)
# Out:
# 256.0

# %%
 200 + (200 * 0.13) + (200 * 0.15)
# Out:
# 256.0

# %%
calc_total_bill(200, 0.18)
# Out:
# 266.0

# %%
calc_total_bill(200, tip_rate=0.18)
# Out:
# 262.0

# %%
help(calc_total_bill)
# Out:
# Help on function calc_total_bill in module __main__:
#
# calc_total_bill(price, tax_rate=0.13, tip_rate=0.15)
#     calculate total bill with tax and tip

# %%
output = 60

# %%
output
# Out:
# 60

# %%
favourite_food ="mashed potatoes"

# %%
favourite_food
# Out:
# 'mashed potatoes'

# %%
"Let's see if this works"
# Out:
# "Let's see if this works"

# %%
''''''I am a multiline
       many
       many
       line  
       of   
        code """"""
# Out:
#   Cell In[28], line 1
#     ''''''I am a multiline
#           ^
# SyntaxError: invalid syntax

# %%
print("This is\ta tab")
# Out:
# This is	a tab

# %%
print("This is\na newline")
# Out:
# This is
# a newline

# %%
print("Tis is \\ a backslash")
# Out:
# Tis is \ a backslash

# %%
print("This is\" a double quote")
# Out:
# This is" a double quote

# %%
1 + 1
# Out:
# 2

# %%
'hello' + 'world'
# Out:
# 'helloworld'

# %%
'ha'  * 3
# Out:
# 'hahaha'

# %%
'hello' + 2020
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 'hello' + 2020
#
# TypeError: can only concatenate str (not "int") to str

# %%
'apple'=='Apple'
# Out:
# False

# %%
'apple' != 'Apple'
# Out:
# True

# %%
'20'==20
# Out:
# False

# %%
first_name ='Ada'
last_name = 'Lovelace'

# %%
first_name[2]
# Out:
# 'a'

# %%
last_name[6]
# Out:
# 'c'

# %%
last_name[1:5]
# Out:
# 'ovel'

# %%
last_name[3:5]
# Out:
# 'el'

# %%
last_name[0:6]
# Out:
# 'Lovela'

# %%
last_name[:6]
# Out:
# 'Lovela'

# %%
last_name[3:]
# Out:
# 'elace'

# %%
last_name[:]
# Out:
# 'Lovelace'

# %%
last_name[-3:]
# Out:
# 'ace'

# %%
last_name[-3:7]
# Out:
# 'ac'

# %%
last_name[1:6:2]
# Out:
# 'oea'

# %%
last_name[-1:-5:-1]
# Out:
# 'ecal'

# %%
phone_number = '+1 555-123-4567'

# %%
phone_number[3:6]
# Out:
# '555'

# %%
print(1, "fish", 2, "fish")
# Out:
# 1 fish 2 fish

# %%
len("gnaldkfgjalfnklasmkflmaklsmlak")
# Out:
# 30

# %%
sorted( "banana")
# Out:
# ['a', 'a', 'a', 'b', 'n', 'n']

# %%
'I am not yelling'.upper()
# Out:
# 'I AM NOT YELLING'

# %%
'This string is unusual'.count('e')
# Out:
# 0

# %%
'file_name.csv'.endswith('.csv')
# Out:
# True

# %%
'long file name with spaces.csv'.replace('','_')
# Out:
# '_l_o_n_g_ _f_i_l_e_ _n_a_m_e_ _w_i_t_h_ _s_p_a_c_e_s_._c_s_v_'

# %%
first_name
# Out:
# 'Ada'

# %%
last_name
# Out:
# 'Lovelace'

# %%
# .format() string method
'Ada Lovelace\'s initials are {}. {}.' .format(first_name[0], last_name [0])
# Out:
# "Ada Lovelace's initials are A. L."

# %%
'My favourite day of the week is {}.' .format('Monday')
# Out:
# 'My favourite day of the week is Monday.'

# %%
# f-string
My favourite_sport =skiing
f'My favourite sport is{favourite_sport}'
# Out:
#   Cell In[74], line 2
#     My favourite_sport =skiing
#        ^
# SyntaxError: invalid syntax

# %%
'20'+ str(37.5)
# Out:
# '2037.5'

# %%
age = input('how old are you?')

# %%
age
# Out:
# '1000'

# %%
age_next_bday = int(age) + 1

# %%
age
# Out:
# '1000'
