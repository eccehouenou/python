# %%
# logic operators
# not: negate the truth value of the statement

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
3 == 3
# Out:
# True

# %%
not (3 ==3)
# Out:
# False

# %%
# and: check if the statements on both side are true

# %%
True and True
# Out:
# True

# %%
False and True
# Out:
# False

# %%
True and False
# Out:
# False

# %%
False and False
# Out:
# False

# %%
(7 == 7.0) and (32 > 9)
# Out:
# True

# %%
('Python'== 'python') and True
# Out:
# False

# %%
'Python'== 'python'
# Out:
# False

# %%
is_winter = True
is_grey = True
is_winter and is_grey
# Out:
# True

# %%
#or: check if at least one of the statements are true

# %%
True or True
# Out:
# True

# %%
False or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False

# %%
"Phyton"== "python" or True
# Out:
# True

# %%
not (7 % 2 == 1) or False
# Out:
# False

# %%
7 % 2
# Out:
# 1

# %%
"True" or True
# Out:
# 'True'

# %%
"Thursday" or True
# Out:
# 'Thursday'

# %%
# Or return the first truthy value encounter 
# or the last falsy if all operands are false

# %%
year = 2022
if year >= 2000:
    print('We are in the 21 st cenury.')

# %%
'We are in the 21 st cenury.'
# Out:
# 'We are in the 21 st cenury.'

# %%
year = 2024
output = 'no'
if year >= 2000 and output == 'yes':
    print('We are in the 21st century.')

# %%
 year >= 2000 and output == 'yes'
# Out:
# False

# %%
year = 1999

if year >= 2000:
    print('We are in the 21st century.')
  else:
       print('We are not in the 21st century')
# Out:
#   File <tokenize>:5
#     else:
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
# elif short for ''else if''
year = 2002
if year >= 2000:
    print('we are in the 21 st century.')
elif year >=1900:
    print('We are in the 20th century.')
if year >= 1800:
    print('We are in the 19th century.')
else:
    print('We have gone way back in time!')
# Out:
# we are in the 21 st century.
# We are in the 19th century.

# %%
day_of_week = 'Saturday'

if day_of_week =='Saturday' or day_of_week == 'Sunday':
      print ('Weekday')
else:
      print('Weekday')
# Out:
# Weekday

# %%
def eye_exam_covered( age, qualifying_condition, time_since_last_exam):
# assumptions:
# age int
# qualifying_condition bool, True if have an eligible medical condition, False otherwise
# time_since_last_exam int, number of months since last examination

    if age <= 19:
        if time_since_last_exam >= 12:
            return "You are eligible for 1 major eye exam and any minor assessments needed"
        else:
            return "It hasn't been 12 months since your last major eye exam but you can have a minor assessment"  
        
    elif  20 <= age <= 64:
        if qualifying_condition:
            if time_since_last_exam >= 12:
                return "You are eligible for 1 major eye exam and 2 additional follow-up minor assessments"
            else:
                return "It hasn't been 12 months since your last major eye exam, but you have follow-up minor assessments"
        else:
            return "You do not have an elligible medical condition"
    elif age>= 65:
        if time_since_last_exam >= 18:
            return "You are eligible for 1 major exam and 2 followup minor assessments"
        else:
            return "It hasn't been 18 months since your last major exam, but you have 2 followup minor assessments" 
    else:
        return " Invalid age input."
